# %% [markdown]
# ### Instalar las dependencias

# %%
# !pip install tensorflow-transform
# Out:
# Requirement already satisfied: tensorflow-transform in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: absl-py<0.13,>=0.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (0.12.0)
# Requirement already satisfied: tfx-bsl<1.6.0,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (1.5.0)
# Requirement already satisfied: tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (2.7.0)
# Requirement already satisfied: pydot<2,>=1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (1.3.0)
# Requirement already satisfied: pyarrow<6,>=1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (3.0.0)
# Requirement already satisfied: tensorflow-metadata<1.6.0,>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (1.5.0)
# Requirement already satisfied: protobuf<4,>=3.13 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (3.19.1)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.34 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (2.34.0)
# Requirement already satisfied: numpy<1.20,>=1.16 in /usr/local/lib/python3.7/dist-packages (from tensorflow-transform) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py<0.13,>=0.9->tensorflow-transform) (1.15.0)
# Requirement already satisfied: fastavro<2,>=0.21.4 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.4.8)
# Requirement already satisfied: grpcio<2,>=1.29.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.42.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.6.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (3.12.1)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.8.2)
# Requirement already satisfied: future<1.0.0,>=0.18.2 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.18.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.26.0)
# Requirement already satisfied: typing-extensions<4,>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (3.10.0.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2018.9)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (3.6.5)
# Requirement already satisfied: avro-python3!=1.9.2,<1.10.0,>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.9.2.1)
# Requirement already satisfied: httplib2<0.20.0,>=0.8 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.17.4)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.3.1.1)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.7)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (4.1.3)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.35.0)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.0.0)
# Requirement already satisfied: google-cloud-pubsub<2,>=0.39.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.7.0)
# Requirement already satisfied: google-cloud-core<2,>=0.28.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.7.2)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.7.0)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.3.0)
# Requirement already satisfied: google-cloud-datastore<2,>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.8.0)
# Requirement already satisfied: google-cloud-recommendations-ai<=0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.2.0)
# Requirement already satisfied: google-cloud-dlp<2,>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.0.0)
# Requirement already satisfied: grpcio-gcp<1,>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.2.2)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.16.1)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.6.3 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.10.1)
# Requirement already satisfied: cachetools<5,>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (4.2.4)
# Requirement already satisfied: google-cloud-spanner<2,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.19.1)
# Requirement already satisfied: google-cloud-bigquery<3,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.21.0)
# Requirement already satisfied: fasteners>=0.14 in /usr/local/lib/python3.7/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.16.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.2.8)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery<3,>=1.6.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.4.1)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.28.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.31.5)
# Requirement already satisfied: proto-plus>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.19.8)
# Requirement already satisfied: libcst>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.3.23)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.53.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (21.3)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.7/dist-packages (from google-cloud-bigtable<2,>=0.31.1->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.12.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.6.2)
# Requirement already satisfied: pyyaml>=5.2 in /usr/local/lib/python3.7/dist-packages (from libcst>=0.2.5->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (6.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from libcst>=0.2.5->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.7.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core[grpc]<3.0.0dev,>=1.28.0->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (3.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (2.0.8)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (12.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (3.3.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.2.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (2.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (2.7.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.37.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.22.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (3.3.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (3.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<2.8,>=1.15.2->tensorflow-transform) (3.1.1)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /usr/local/lib/python3.7/dist-packages (from tfx-bsl<1.6.0,>=1.5.0->tensorflow-transform) (1.12.8)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.7/dist-packages (from tfx-bsl<1.6.0,>=1.5.0->tensorflow-transform) (1.1.5)
# Requirement already satisfied: tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,<3,>=1.15 in /usr/local/lib/python3.7/dist-packages (from tfx-bsl<1.6.0,>=1.5.0->tensorflow-transform) (2.7.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.6.0,>=1.5.0->tensorflow-transform) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.6.0,>=1.5.0->tensorflow-transform) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-bigquery-storage>=2.6.3->apache-beam[gcp]<3,>=2.34->tensorflow-transform) (0.4.3)

# %% [markdown]
# ### Importar las librerías

# %%
import tempfile # Archivos temporales
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft
import tensorflow_transform.beam.impl as tft_beam 

from __future__ import print_function
from tensorflow_transform.tf_metadata import dataset_metadata

# %% [markdown]
# ### Pre Procesado de datos

# %%
dataset = pd.read_csv('pollution-small.csv')

# %%
dataset.head()
# Out:
#        Date   pm10    no2    so2   soot
# 0  1/1/2009  98.67  14.10  44.38  34.81
# 1  1/2/2009  52.33  14.10  29.75  33.06
# 2  1/3/2009  74.67  20.50  36.25  39.25
# 3  1/4/2009  72.00  17.30  46.44  34.38
# 4  1/5/2009  81.00  25.64  56.56  45.59

# %%
# Eliminar la columna de la fecha
features = dataset.drop('Date', axis = 1)

# %%
features.head()
# Out:
#     pm10    no2    so2   soot
# 0  98.67  14.10  44.38  34.81
# 1  52.33  14.10  29.75  33.06
# 2  74.67  20.50  36.25  39.25
# 3  72.00  17.30  46.44  34.38
# 4  81.00  25.64  56.56  45.59

# %%
# Convertir el dataset a lista de diccionarios de python
dict_features = list(features.to_dict('index').values())

# %%
dict_features[:5]
# Out:
# [{'no2': 14.1, 'pm10': 98.67, 'so2': 44.38, 'soot': 34.81},
#  {'no2': 14.1, 'pm10': 52.33, 'so2': 29.75, 'soot': 33.06},
#  {'no2': 20.5, 'pm10': 74.67, 'so2': 36.25, 'soot': 39.25},
#  {'no2': 17.3, 'pm10': 72.0, 'so2': 46.44, 'soot': 34.38},
#  {'no2': 25.64, 'pm10': 81.0, 'so2': 56.56, 'soot': 45.59}]

# %% [markdown]
# #### Definir los metadatos del dataset

# %%
from tensorflow_transform.tf_metadata import schema_utils

# %%
data_metadata = dataset_metadata.DatasetMetadata(
    schema_utils.schema_from_feature_spec({
        'no2':  tf.io.FixedLenFeature([], tf.float32), # Longitud fija de tipo float
        'so2':  tf.io.FixedLenFeature([], tf.float32), # El shape [] indica que son números y no vectores
        'pm10': tf.io.FixedLenFeature([], tf.float32),
        'soot': tf.io.FixedLenFeature([], tf.float32),
    })
)

# %%
data_metadata
# Out:
# {'_schema': feature {
#   name: "no2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "pm10"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "so2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "soot"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# }

# %% [markdown]
# #### Función preprocesing

# %%
def preprocessing_fn(inputs):

  no2 = inputs['no2']
  pm10 = inputs['pm10']
  so2 = inputs['so2']
  soot = inputs['soot']

  no2_normalized = no2 - tft.mean(no2)
  so2_normalized = no2 - tft.mean(so2)

  pm10_normalized = tft.scale_to_0_1(pm10)
  soot_normalized = tft.scale_by_min_max(soot)

  return {
      'no2_normalized': no2_normalized,
      'so2_normalized': so2_normalized,
      'pm10_normalized': pm10_normalized,
      'soot_normalized': soot_normalized
  }

# %% [markdown]
# TensorFlow Transform utiliza **Apache Beam** en segundo plano para llevar a cabo transformaciones de datos escalables. En esta función usaremos un ejecutor directo (direct runner)

# %% [markdown]
# Argumentos para el ejecutor
#
# * `dict_features` - Nuestro dataset convertido a diccionario de python
# * `data_metadata` - Los meta datos de nuestro dataset que hemos creado
# * `preprocessing_fn` - La función de pre procesado principal. Se llamará para aplicar la operacion de pre procesado columna a columna

# %% [markdown]
# La sintaxis de Apache Beam es especial. Se utiliza para apilar operaciones e invocar transformaciones en nuestros datos en forma de _pipe_.
#
# En nuestro caso sería
# * **resultado** -> transformed_dataset, transform_fn
# * **dato_a_pasar** -> (dict_features, data_metadata)
# * **donde_pasar_el_dato** -> tft_beam.AnalyzeAndTransformDataset(preprocessing_fn)
#
# transformed_dataset, transform_fn = ((dict_features, data_metadata ) |
# tft_beam.AnalyzeAndTransformDataset((preprocessing_fn))

# %%
def data_transform():

  with tft_beam.Context( temp_dir = tempfile.mkdtemp()):
    transformed_dataset, transform_fn = ((dict_features, data_metadata ) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))

  transformed_data, transformed_metadata = transformed_dataset

  for i in range(len(transformed_data)):
    print('Raw: ', dict_features[i])
    print('Transformed: ', transformed_data[i])

# %%
data_transform()
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_transform/tf_utils.py:289: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_transform/tf_utils.py:289: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-c0dc2044-2469-4135-8049-6a909a0713e1.json']
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# INFO:tensorflow:Assets written to: /tmp/tmpegjjkvr0/tftransform_tmp/7959d02514564bb2ba7b2bb96eaa217c/assets
# INFO:tensorflow:Assets written to: /tmp/tmpegjjkvr0/tftransform_tmp/7959d02514564bb2ba7b2bb96eaa217c/assets
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:Assets written to: /tmp/tmpegjjkvr0/tftransform_tmp/548baaa1427e45b38b340b2423b2cba6/assets
# INFO:tensorflow:Assets written to: /tmp/tmpegjjkvr0/tftransform_tmp/548baaa1427e45b38b340b2423b2cba6/assets
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# Raw:  {'pm10': 98.67, 'no2': 14.1, 'so2': 44.38, 'soot': 34.81}
# Transformed:  {'no2_normalized': -18.577978, 'pm10_normalized': 0.34071696, 'so2_normalized': -1.424593, 'soot_normalized': 0.2834235}
# Raw:  {'pm10': 52.33, 'no2': 14.1, 'so2': 29.75, 'soot': 33.06}
# Transformed:  {'no2_normalized': -18.577978, 'pm10_normalized': 0.16963857, 'so2_normalized': -1.424593, 'soot_normalized': 0.26620758}
# Raw:  {'pm10': 74.67, 'no2': 20.5, 'so2': 36.25, 'soot': 39.25}
# Transformed:  {'no2_normalized': -12.1779785, 'pm10_normalized': 0.25211358, 'so2_normalized': 4.9754066, 'soot_normalized': 0.3271028}
# Raw:  {'pm10': 72.0, 'no2': 17.3, 'so2': 46.44, 'soot': 34.38}
# Transformed:  {'no2_normalized': -15.377979, 'pm10_normalized': 0.24225645, 'so2_normalized': 1.7754059, 'soot_normalized': 0.2791933}
# Raw:  {'pm10': 81.0, 'no2': 25.64, 'so2': 56.56, 'soot': 45.59}
# Transformed:  {'no2_normalized': -7.037979, 'pm10_normalized': 0.2754827, 'so2_normalized': 10.115406, 'soot_normalized': 0.38947368}
# Raw:  {'pm10': 147.0, 'no2': 25.2, 'so2': 42.38, 'soot': 69.33}
# Transformed:  {'no2_normalized': -7.4779778, 'pm10_normalized': 0.51914203, 'so2_normalized': 9.675407, 'soot_normalized': 0.6230202}
# Raw:  {'pm10': 185.0, 'no2': 21.91, 'so2': 71.69, 'soot': 84.06}
# Transformed:  {'no2_normalized': -10.767979, 'pm10_normalized': 0.65943074, 'so2_normalized': 6.3854065, 'soot_normalized': 0.76792914}
# Raw:  {'pm10': 148.67, 'no2': 25.09, 'so2': 51.75, 'soot': 74.41}
# Transformed:  {'no2_normalized': -7.5879784, 'pm10_normalized': 0.52530736, 'so2_normalized': 9.565407, 'soot_normalized': 0.6729956}
# Raw:  {'pm10': 216.0, 'no2': 37.27, 'so2': 63.47, 'soot': 64.06}
# Transformed:  {'no2_normalized': 4.592022, 'pm10_normalized': 0.7738768, 'so2_normalized': 21.745407, 'soot_normalized': 0.5711756}
# Raw:  {'pm10': 135.67, 'no2': 23.18, 'so2': 63.13, 'soot': 58.94}
# Transformed:  {'no2_normalized': -9.497978, 'pm10_normalized': 0.47731382, 'so2_normalized': 7.655407, 'soot_normalized': 0.52080667}
# Raw:  {'pm10': 138.67, 'no2': 21.64, 'so2': 67.56, 'soot': 49.65}
# Transformed:  {'no2_normalized': -11.037979, 'pm10_normalized': 0.48838925, 'so2_normalized': 6.115406, 'soot_normalized': 0.42941466}
# Raw:  {'pm10': 96.67, 'no2': 21.0, 'so2': 84.24, 'soot': 49.83}
# Transformed:  {'no2_normalized': -11.6779785, 'pm10_normalized': 0.33333334, 'so2_normalized': 5.4754066, 'soot_normalized': 0.43118545}
# Raw:  {'pm10': 101.0, 'no2': 22.64, 'so2': 83.06, 'soot': 46.44}
# Transformed:  {'no2_normalized': -10.037979, 'pm10_normalized': 0.3493189, 'so2_normalized': 7.115406, 'soot_normalized': 0.3978357}
# Raw:  {'pm10': 129.33, 'no2': 25.42, 'so2': 78.11, 'soot': 55.53}
# Transformed:  {'no2_normalized': -7.2579784, 'pm10_normalized': 0.45390782, 'so2_normalized': 9.895407, 'soot_normalized': 0.4872602}
# Raw:  {'pm10': 101.0, 'no2': 21.42, 'so2': 52.44, 'soot': 42.42}
# Transformed:  {'no2_normalized': -11.257978, 'pm10_normalized': 0.3493189, 'so2_normalized': 5.8954067, 'soot_normalized': 0.35828823}
# Raw:  {'pm10': 83.67, 'no2': 47.08, 'so2': 44.94, 'soot': 39.84}
# Transformed:  {'no2_normalized': 14.402023, 'pm10_normalized': 0.28533983, 'so2_normalized': 31.555408, 'soot_normalized': 0.33290702}
# Raw:  {'pm10': 88.67, 'no2': 24.75, 'so2': 41.67, 'soot': 47.79}
# Transformed:  {'no2_normalized': -7.9279785, 'pm10_normalized': 0.30379888, 'so2_normalized': 9.225407, 'soot_normalized': 0.41111657}
# Raw:  {'pm10': 149.33, 'no2': 34.75, 'so2': 87.22, 'soot': 83.79}
# Transformed:  {'no2_normalized': 2.0720215, 'pm10_normalized': 0.52774394, 'so2_normalized': 19.225407, 'soot_normalized': 0.765273}
# Raw:  {'pm10': 41.0, 'no2': 32.08, 'so2': 52.89, 'soot': 46.42}
# Transformed:  {'no2_normalized': -0.5979767, 'pm10_normalized': 0.12781039, 'so2_normalized': 16.555408, 'soot_normalized': 0.39763895}
# Raw:  {'pm10': 46.33, 'no2': 26.5, 'so2': 36.5, 'soot': 27.76}
# Transformed:  {'no2_normalized': -6.1779785, 'pm10_normalized': 0.14748773, 'so2_normalized': 10.975407, 'soot_normalized': 0.21406788}
# Raw:  {'pm10': 26.67, 'no2': 19.67, 'so2': 28.59, 'soot': 16.28}
# Transformed:  {'no2_normalized': -13.007978, 'pm10_normalized': 0.07490679, 'so2_normalized': 4.1454067, 'soot_normalized': 0.101131335}
# Raw:  {'pm10': 28.33, 'no2': 23.42, 'so2': 19.82, 'soot': 18.17}
# Transformed:  {'no2_normalized': -9.257978, 'pm10_normalized': 0.08103519, 'so2_normalized': 7.8954067, 'soot_normalized': 0.11972454}
# Raw:  {'pm10': 40.67, 'no2': 25.58, 'so2': 17.94, 'soot': 28.56}
# Transformed:  {'no2_normalized': -7.0979786, 'pm10_normalized': 0.12659208, 'so2_normalized': 10.055407, 'soot_normalized': 0.22193801}
# Raw:  {'pm10': 38.0, 'no2': 30.33, 'so2': 19.88, 'soot': 27.39}
# Transformed:  {'no2_normalized': -2.3479786, 'pm10_normalized': 0.11673497, 'so2_normalized': 14.805407, 'soot_normalized': 0.21042792}
# Raw:  {'pm10': 25.0, 'no2': 25.33, 'so2': 16.88, 'soot': 16.17}
# Transformed:  {'no2_normalized': -7.3479786, 'pm10_normalized': 0.06874146, 'so2_normalized': 9.805407, 'soot_normalized': 0.10004919}
# Raw:  {'pm10': 48.67, 'no2': 32.5, 'so2': 20.35, 'soot': 29.11}
# Transformed:  {'no2_normalized': -0.17797852, 'pm10_normalized': 0.15612654, 'so2_normalized': 16.975407, 'soot_normalized': 0.22734874}
# Raw:  {'pm10': 35.67, 'no2': 27.42, 'so2': 25.47, 'soot': 22.28}
# Transformed:  {'no2_normalized': -5.2579784, 'pm10_normalized': 0.10813304, 'so2_normalized': 11.895407, 'soot_normalized': 0.16015741}
# Raw:  {'pm10': 21.33, 'no2': 18.83, 'so2': 15.83, 'soot': 19.88}
# Transformed:  {'no2_normalized': -13.847979, 'pm10_normalized': 0.055192526, 'so2_normalized': 3.3054066, 'soot_normalized': 0.13654697}
# Raw:  {'pm10': 16.67, 'no2': 17.5, 'so2': 14.44, 'soot': 23.71}
# Transformed:  {'no2_normalized': -15.1779785, 'pm10_normalized': 0.037988704, 'so2_normalized': 1.9754066, 'soot_normalized': 0.17422527}
# Raw:  {'pm10': 29.33, 'no2': 15.42, 'so2': 15.28, 'soot': 27.61}
# Transformed:  {'no2_normalized': -17.257978, 'pm10_normalized': 0.084727, 'so2_normalized': -0.10459328, 'soot_normalized': 0.21259223}
# Raw:  {'pm10': 31.33, 'no2': 17.0, 'so2': 17.39, 'soot': 24.33}
# Transformed:  {'no2_normalized': -15.6779785, 'pm10_normalized': 0.09211061, 'so2_normalized': 1.4754066, 'soot_normalized': 0.18032464}
# Raw:  {'pm10': 25.67, 'no2': 14.58, 'so2': 20.39, 'soot': 23.0}
# Transformed:  {'no2_normalized': -18.097979, 'pm10_normalized': 0.07121498, 'so2_normalized': -0.9445934, 'soot_normalized': 0.16724053}
# Raw:  {'pm10': 21.33, 'no2': 14.92, 'so2': 25.11, 'soot': 19.78}
# Transformed:  {'no2_normalized': -17.757978, 'pm10_normalized': 0.055192526, 'so2_normalized': -0.6045933, 'soot_normalized': 0.13556321}
# Raw:  {'pm10': 19.67, 'no2': 10.42, 'so2': 20.88, 'soot': 19.79}
# Transformed:  {'no2_normalized': -22.257978, 'pm10_normalized': 0.049064126, 'so2_normalized': -5.1045933, 'soot_normalized': 0.13566159}
# Raw:  {'pm10': 49.67, 'no2': 14.58, 'so2': 19.22, 'soot': 29.84}
# Transformed:  {'no2_normalized': -18.097979, 'pm10_normalized': 0.15981835, 'so2_normalized': -0.9445934, 'soot_normalized': 0.23453026}
# Raw:  {'pm10': 62.0, 'no2': 30.08, 'so2': 27.06, 'soot': 48.0}
# Transformed:  {'no2_normalized': -2.5979786, 'pm10_normalized': 0.20533836, 'so2_normalized': 14.555407, 'soot_normalized': 0.4131825}
# Raw:  {'pm10': 30.67, 'no2': 27.67, 'so2': 21.61, 'soot': 35.68}
# Transformed:  {'no2_normalized': -5.0079784, 'pm10_normalized': 0.08967402, 'so2_normalized': 12.145407, 'soot_normalized': 0.2919823}
# Raw:  {'pm10': 29.33, 'no2': 19.58, 'so2': 16.39, 'soot': 23.11}
# Transformed:  {'no2_normalized': -13.097979, 'pm10_normalized': 0.084727, 'so2_normalized': 4.0554066, 'soot_normalized': 0.16832268}
# Raw:  {'pm10': 27.0, 'no2': 16.17, 'so2': 15.11, 'soot': 23.79}
# Transformed:  {'no2_normalized': -16.507978, 'pm10_normalized': 0.07612508, 'so2_normalized': 0.6454067, 'soot_normalized': 0.1750123}
# Raw:  {'pm10': 12.67, 'no2': 14.5, 'so2': 11.5, 'soot': 15.94}
# Transformed:  {'no2_normalized': -18.177979, 'pm10_normalized': 0.023221472, 'so2_normalized': -1.0245934, 'soot_normalized': 0.097786516}
# Raw:  {'pm10': 30.33, 'no2': 25.0, 'so2': 17.67, 'soot': 30.05}
# Transformed:  {'no2_normalized': -7.6779785, 'pm10_normalized': 0.088418804, 'so2_normalized': 9.475407, 'soot_normalized': 0.23659615}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 15.56, 'soot': 24.05}
# Transformed:  {'no2_normalized': -11.6779785, 'pm10_normalized': 0.05766604, 'so2_normalized': 5.4754066, 'soot_normalized': 0.17757009}
# Raw:  {'pm10': 18.33, 'no2': 17.82, 'so2': 14.33, 'soot': 17.21}
# Transformed:  {'no2_normalized': -14.857979, 'pm10_normalized': 0.044117104, 'so2_normalized': 2.2954063, 'soot_normalized': 0.110280365}
# Raw:  {'pm10': 21.33, 'no2': 17.55, 'so2': 17.35, 'soot': 17.83}
# Transformed:  {'no2_normalized': -15.127979, 'pm10_normalized': 0.055192526, 'so2_normalized': 2.025406, 'soot_normalized': 0.11637973}
# Raw:  {'pm10': 24.0, 'no2': 15.91, 'so2': 13.76, 'soot': 16.94}
# Transformed:  {'no2_normalized': -16.767979, 'pm10_normalized': 0.065049656, 'so2_normalized': 0.3854065, 'soot_normalized': 0.1076242}
# Raw:  {'pm10': 18.67, 'no2': 12.91, 'so2': 13.35, 'soot': 14.89}
# Transformed:  {'no2_normalized': -19.767979, 'pm10_normalized': 0.04537232, 'so2_normalized': -2.6145935, 'soot_normalized': 0.087456964}
# Raw:  {'pm10': 35.33, 'no2': 23.18, 'so2': 16.35, 'soot': 22.06}
# Transformed:  {'no2_normalized': -9.497978, 'pm10_normalized': 0.10687784, 'so2_normalized': 7.655407, 'soot_normalized': 0.15799311}
# Raw:  {'pm10': 37.0, 'no2': 32.27, 'so2': 21.65, 'soot': 33.83}
# Transformed:  {'no2_normalized': -0.40797806, 'pm10_normalized': 0.11304315, 'so2_normalized': 16.745407, 'soot_normalized': 0.2737826}
# Raw:  {'pm10': 33.33, 'no2': 19.33, 'so2': 16.28, 'soot': 25.68}
# Transformed:  {'no2_normalized': -13.347979, 'pm10_normalized': 0.09949423, 'so2_normalized': 3.8054066, 'soot_normalized': 0.19360551}
# Raw:  {'pm10': 20.0, 'no2': 13.67, 'so2': 18.56, 'soot': 19.53}
# Transformed:  {'no2_normalized': -19.007978, 'pm10_normalized': 0.050282422, 'so2_normalized': -1.8545933, 'soot_normalized': 0.13310379}
# Raw:  {'pm10': 34.33, 'no2': 19.92, 'so2': 15.33, 'soot': 21.89}
# Transformed:  {'no2_normalized': -12.757978, 'pm10_normalized': 0.10318603, 'so2_normalized': 4.3954067, 'soot_normalized': 0.1563207}
# Raw:  {'pm10': 52.67, 'no2': 23.0, 'so2': 17.33, 'soot': 29.32}
# Transformed:  {'no2_normalized': -9.6779785, 'pm10_normalized': 0.17089377, 'so2_normalized': 7.4754066, 'soot_normalized': 0.22941466}
# Raw:  {'pm10': 75.33, 'no2': 23.17, 'so2': 13.78, 'soot': 35.26}
# Transformed:  {'no2_normalized': -9.507978, 'pm10_normalized': 0.2545502, 'so2_normalized': 7.6454067, 'soot_normalized': 0.28785044}
# Raw:  {'pm10': 114.33, 'no2': 39.58, 'so2': 31.72, 'soot': 53.37}
# Transformed:  {'no2_normalized': 6.9020233, 'pm10_normalized': 0.3985307, 'so2_normalized': 24.055408, 'soot_normalized': 0.4660108}
# Raw:  {'pm10': 123.0, 'no2': 39.08, 'so2': 35.06, 'soot': 52.26}
# Transformed:  {'no2_normalized': 6.4020233, 'pm10_normalized': 0.43053865, 'so2_normalized': 23.555408, 'soot_normalized': 0.45509097}
# Raw:  {'pm10': 89.0, 'no2': 29.92, 'so2': 23.06, 'soot': 39.63}
# Transformed:  {'no2_normalized': -2.7579784, 'pm10_normalized': 0.30501717, 'so2_normalized': 14.395407, 'soot_normalized': 0.33084112}
# Raw:  {'pm10': 72.33, 'no2': 31.0, 'so2': 23.72, 'soot': 37.89}
# Transformed:  {'no2_normalized': -1.6779785, 'pm10_normalized': 0.24347475, 'so2_normalized': 15.475407, 'soot_normalized': 0.31372356}
# Raw:  {'pm10': 44.33, 'no2': 29.58, 'so2': 23.94, 'soot': 35.47}
# Transformed:  {'no2_normalized': -3.0979786, 'pm10_normalized': 0.14010412, 'so2_normalized': 14.055407, 'soot_normalized': 0.2899164}
# Raw:  {'pm10': 36.67, 'no2': 31.5, 'so2': 20.72, 'soot': 35.47}
# Transformed:  {'no2_normalized': -1.1779785, 'pm10_normalized': 0.111824855, 'so2_normalized': 15.975407, 'soot_normalized': 0.2899164}
# Raw:  {'pm10': 75.5, 'no2': 35.13, 'so2': 28.65, 'soot': 48.47}
# Transformed:  {'no2_normalized': 2.4520226, 'pm10_normalized': 0.25517777, 'so2_normalized': 19.605408, 'soot_normalized': 0.4178062}
# Raw:  {'pm10': 56.75, 'no2': 30.25, 'so2': 26.5, 'soot': 41.53}
# Transformed:  {'no2_normalized': -2.4279785, 'pm10_normalized': 0.18595636, 'so2_normalized': 14.725407, 'soot_normalized': 0.3495327}
# Raw:  {'pm10': 56.5, 'no2': 27.94, 'so2': 27.9, 'soot': 43.32}
# Transformed:  {'no2_normalized': -4.737978, 'pm10_normalized': 0.18503341, 'so2_normalized': 12.415407, 'soot_normalized': 0.36714214}
# Raw:  {'pm10': 38.5, 'no2': 16.75, 'so2': 19.0, 'soot': 26.11}
# Transformed:  {'no2_normalized': -15.9279785, 'pm10_normalized': 0.11858087, 'so2_normalized': 1.2254066, 'soot_normalized': 0.19783571}
# Raw:  {'pm10': 22.75, 'no2': 10.56, 'so2': 15.75, 'soot': 21.11}
# Transformed:  {'no2_normalized': -22.117977, 'pm10_normalized': 0.060434893, 'so2_normalized': -4.964593, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 33.0, 'no2': 17.81, 'so2': 15.8, 'soot': 23.79}
# Transformed:  {'no2_normalized': -14.867979, 'pm10_normalized': 0.09827592, 'so2_normalized': 2.285406, 'soot_normalized': 0.1750123}
# Raw:  {'pm10': 29.83, 'no2': 15.81, 'so2': 11.35, 'soot': 18.21}
# Transformed:  {'no2_normalized': -16.867977, 'pm10_normalized': 0.0865729, 'so2_normalized': 0.28540707, 'soot_normalized': 0.120118044}
# Raw:  {'pm10': 31.17, 'no2': 17.44, 'so2': 11.9, 'soot': 22.32}
# Transformed:  {'no2_normalized': -15.237978, 'pm10_normalized': 0.09151992, 'so2_normalized': 1.9154072, 'soot_normalized': 0.1605509}
# Raw:  {'pm10': 33.17, 'no2': 22.81, 'so2': 17.1, 'soot': 26.16}
# Transformed:  {'no2_normalized': -9.867979, 'pm10_normalized': 0.09890352, 'so2_normalized': 7.285406, 'soot_normalized': 0.19832759}
# Raw:  {'pm10': 42.0, 'no2': 20.75, 'so2': 14.5, 'soot': 25.11}
# Transformed:  {'no2_normalized': -11.9279785, 'pm10_normalized': 0.1315022, 'so2_normalized': 5.2254066, 'soot_normalized': 0.18799804}
# Raw:  {'pm10': 32.67, 'no2': 22.13, 'so2': 17.85, 'soot': 24.83}
# Transformed:  {'no2_normalized': -10.547979, 'pm10_normalized': 0.09705762, 'so2_normalized': 6.605406, 'soot_normalized': 0.18524347}
# Raw:  {'pm10': 25.2, 'no2': 17.44, 'so2': 14.25, 'soot': 22.0}
# Transformed:  {'no2_normalized': -15.237978, 'pm10_normalized': 0.06947982, 'so2_normalized': 1.9154072, 'soot_normalized': 0.15740284}
# Raw:  {'pm10': 25.67, 'no2': 18.13, 'so2': 16.2, 'soot': 20.22}
# Transformed:  {'no2_normalized': -14.547979, 'pm10_normalized': 0.07121498, 'so2_normalized': 2.6054058, 'soot_normalized': 0.13989177}
# Raw:  {'pm10': 42.0, 'no2': 18.06, 'so2': 14.0, 'soot': 21.83}
# Transformed:  {'no2_normalized': -14.617979, 'pm10_normalized': 0.1315022, 'so2_normalized': 2.535406, 'soot_normalized': 0.15573044}
# Raw:  {'pm10': 72.0, 'no2': 25.44, 'so2': 25.25, 'soot': 35.72}
# Transformed:  {'no2_normalized': -7.237978, 'pm10_normalized': 0.24225645, 'so2_normalized': 9.915407, 'soot_normalized': 0.2923758}
# Raw:  {'pm10': 38.83, 'no2': 18.69, 'so2': 16.55, 'soot': 20.33}
# Transformed:  {'no2_normalized': -13.987978, 'pm10_normalized': 0.11979917, 'so2_normalized': 3.1654072, 'soot_normalized': 0.14097393}
# Raw:  {'pm10': 41.33, 'no2': 17.19, 'so2': 13.65, 'soot': 18.78}
# Transformed:  {'no2_normalized': -15.487978, 'pm10_normalized': 0.1290287, 'so2_normalized': 1.6654072, 'soot_normalized': 0.12572554}
# Raw:  {'pm10': 23.17, 'no2': 12.38, 'so2': 11.7, 'soot': 16.06}
# Transformed:  {'no2_normalized': -20.297977, 'pm10_normalized': 0.06198546, 'so2_normalized': -3.1445932, 'soot_normalized': 0.09896704}
# Raw:  {'pm10': 27.0, 'no2': 16.63, 'so2': 12.3, 'soot': 18.28}
# Transformed:  {'no2_normalized': -16.04798, 'pm10_normalized': 0.07612508, 'so2_normalized': 1.1054058, 'soot_normalized': 0.120806694}
# Raw:  {'pm10': 38.33, 'no2': 18.75, 'so2': 15.0, 'soot': 19.05}
# Transformed:  {'no2_normalized': -13.9279785, 'pm10_normalized': 0.11795326, 'so2_normalized': 3.2254066, 'soot_normalized': 0.1283817}
# Raw:  {'pm10': 26.6, 'no2': 15.75, 'so2': 13.55, 'soot': 15.74}
# Transformed:  {'no2_normalized': -16.927979, 'pm10_normalized': 0.07464836, 'so2_normalized': 0.22540665, 'soot_normalized': 0.09581898}
# Raw:  {'pm10': 31.0, 'no2': 14.94, 'so2': 12.4, 'soot': 16.42}
# Transformed:  {'no2_normalized': -17.73798, 'pm10_normalized': 0.09089231, 'so2_normalized': -0.5845938, 'soot_normalized': 0.102508605}
# Raw:  {'pm10': 28.0, 'no2': 20.0, 'so2': 14.15, 'soot': 17.79}
# Transformed:  {'no2_normalized': -12.6779785, 'pm10_normalized': 0.079816885, 'so2_normalized': 4.4754066, 'soot_normalized': 0.115986235}
# Raw:  {'pm10': 21.83, 'no2': 21.27, 'so2': 13.5, 'soot': 14.59}
# Transformed:  {'no2_normalized': -11.407978, 'pm10_normalized': 0.057038434, 'so2_normalized': 5.745407, 'soot_normalized': 0.084505655}
# Raw:  {'pm10': 28.83, 'no2': 18.57, 'so2': 12.6, 'soot': 17.0}
# Transformed:  {'no2_normalized': -14.107979, 'pm10_normalized': 0.08288109, 'so2_normalized': 3.0454063, 'soot_normalized': 0.10821446}
# Raw:  {'pm10': 34.67, 'no2': 26.33, 'so2': 17.4, 'soot': 21.24}
# Transformed:  {'no2_normalized': -6.3479786, 'pm10_normalized': 0.10444123, 'so2_normalized': 10.805407, 'soot_normalized': 0.14992622}
# Raw:  {'pm10': 34.17, 'no2': 28.0, 'so2': 17.95, 'soot': 20.88}
# Transformed:  {'no2_normalized': -4.6779785, 'pm10_normalized': 0.10259533, 'so2_normalized': 12.475407, 'soot_normalized': 0.14638464}
# Raw:  {'pm10': 27.33, 'no2': 22.6, 'so2': 14.85, 'soot': 16.71}
# Transformed:  {'no2_normalized': -10.077978, 'pm10_normalized': 0.07734338, 'so2_normalized': 7.075407, 'soot_normalized': 0.10536152}
# Raw:  {'pm10': 47.83, 'no2': 13.29, 'so2': 10.95, 'soot': 15.88}
# Transformed:  {'no2_normalized': -19.387978, 'pm10_normalized': 0.15302545, 'so2_normalized': -2.2345934, 'soot_normalized': 0.09719626}
# Raw:  {'pm10': 29.83, 'no2': 19.57, 'so2': 12.05, 'soot': 16.82}
# Transformed:  {'no2_normalized': -13.107979, 'pm10_normalized': 0.0865729, 'so2_normalized': 4.0454063, 'soot_normalized': 0.10644367}
# Raw:  {'pm10': 34.2, 'no2': 19.21, 'so2': 9.9, 'soot': 19.44}
# Transformed:  {'no2_normalized': -13.467979, 'pm10_normalized': 0.1027061, 'so2_normalized': 3.6854057, 'soot_normalized': 0.1322184}
# Raw:  {'pm10': 60.83, 'no2': 19.47, 'so2': 12.55, 'soot': 24.65}
# Transformed:  {'no2_normalized': -13.207979, 'pm10_normalized': 0.20101894, 'so2_normalized': 3.945406, 'soot_normalized': 0.1834727}
# Raw:  {'pm10': 39.17, 'no2': 17.46, 'so2': 10.95, 'soot': 20.5}
# Transformed:  {'no2_normalized': -15.217979, 'pm10_normalized': 0.12105437, 'so2_normalized': 1.9354057, 'soot_normalized': 0.14264633}
# Raw:  {'pm10': 27.5, 'no2': 16.07, 'so2': 10.3, 'soot': 16.27}
# Transformed:  {'no2_normalized': -16.607979, 'pm10_normalized': 0.07797098, 'so2_normalized': 0.54540634, 'soot_normalized': 0.10103296}
# Raw:  {'pm10': 35.33, 'no2': 20.93, 'so2': 11.7, 'soot': 21.27}
# Transformed:  {'no2_normalized': -11.747978, 'pm10_normalized': 0.10687784, 'so2_normalized': 5.405407, 'soot_normalized': 0.15022135}
# Raw:  {'pm10': 51.83, 'no2': 31.07, 'so2': 12.45, 'soot': 29.2}
# Transformed:  {'no2_normalized': -1.6079788, 'pm10_normalized': 0.16779268, 'so2_normalized': 15.545406, 'soot_normalized': 0.22823414}
# Raw:  {'pm10': 53.6, 'no2': 29.0, 'so2': 14.1, 'soot': 27.6}
# Transformed:  {'no2_normalized': -3.6779785, 'pm10_normalized': 0.17432716, 'so2_normalized': 13.475407, 'soot_normalized': 0.21249385}
# Raw:  {'pm10': 48.0, 'no2': 30.36, 'so2': 12.9, 'soot': 27.63}
# Transformed:  {'no2_normalized': -2.317978, 'pm10_normalized': 0.15365304, 'so2_normalized': 14.835407, 'soot_normalized': 0.21278897}
# Raw:  {'pm10': 39.0, 'no2': 30.8, 'so2': 11.25, 'soot': 32.88}
# Transformed:  {'no2_normalized': -1.8779793, 'pm10_normalized': 0.120426774, 'so2_normalized': 15.275406, 'soot_normalized': 0.2644368}
# Raw:  {'pm10': 65.8, 'no2': 34.33, 'so2': 14.15, 'soot': 42.71}
# Transformed:  {'no2_normalized': 1.6520233, 'pm10_normalized': 0.21936724, 'so2_normalized': 18.805408, 'soot_normalized': 0.36114115}
# Raw:  {'pm10': 61.4, 'no2': 38.6, 'so2': 19.2, 'soot': 42.67}
# Transformed:  {'no2_normalized': 5.92202, 'pm10_normalized': 0.20312327, 'so2_normalized': 23.075405, 'soot_normalized': 0.36074764}
# Raw:  {'pm10': 39.17, 'no2': 18.0, 'so2': 10.3, 'soot': 18.61}
# Transformed:  {'no2_normalized': -14.6779785, 'pm10_normalized': 0.12105437, 'so2_normalized': 2.4754066, 'soot_normalized': 0.12405313}
# Raw:  {'pm10': 35.33, 'no2': 15.27, 'so2': 9.8, 'soot': 12.89}
# Transformed:  {'no2_normalized': -17.407978, 'pm10_normalized': 0.10687784, 'so2_normalized': -0.2545929, 'soot_normalized': 0.067781605}
# Raw:  {'pm10': 44.0, 'no2': 15.36, 'so2': 8.8, 'soot': 13.94}
# Transformed:  {'no2_normalized': -17.317978, 'pm10_normalized': 0.13888581, 'so2_normalized': -0.1645937, 'soot_normalized': 0.07811116}
# Raw:  {'pm10': 32.83, 'no2': 22.57, 'so2': 11.6, 'soot': 24.76}
# Transformed:  {'no2_normalized': -10.107979, 'pm10_normalized': 0.09764832, 'so2_normalized': 7.0454063, 'soot_normalized': 0.18455485}
# Raw:  {'pm10': 40.83, 'no2': 25.5, 'so2': 12.3, 'soot': 29.24}
# Transformed:  {'no2_normalized': -7.1779785, 'pm10_normalized': 0.12718278, 'so2_normalized': 9.975407, 'soot_normalized': 0.22862764}
# Raw:  {'pm10': 45.67, 'no2': 39.69, 'so2': 14.7, 'soot': 42.74}
# Transformed:  {'no2_normalized': 7.01202, 'pm10_normalized': 0.14505112, 'so2_normalized': 24.165405, 'soot_normalized': 0.3614363}
# Raw:  {'pm10': 27.67, 'no2': 24.13, 'so2': 10.5, 'soot': 17.84}
# Transformed:  {'no2_normalized': -8.547979, 'pm10_normalized': 0.078598596, 'so2_normalized': 8.605406, 'soot_normalized': 0.11647811}
# Raw:  {'pm10': 24.67, 'no2': 22.94, 'so2': 9.45, 'soot': 17.11}
# Transformed:  {'no2_normalized': -9.737978, 'pm10_normalized': 0.067523174, 'so2_normalized': 7.415407, 'soot_normalized': 0.10929661}
# Raw:  {'pm10': 34.0, 'no2': 23.31, 'so2': 9.55, 'soot': 23.05}
# Transformed:  {'no2_normalized': -9.367979, 'pm10_normalized': 0.10196773, 'so2_normalized': 7.785406, 'soot_normalized': 0.1677324}
# Raw:  {'pm10': 28.17, 'no2': 23.75, 'so2': 9.2, 'soot': 19.68}
# Transformed:  {'no2_normalized': -8.9279785, 'pm10_normalized': 0.0804445, 'so2_normalized': 8.225407, 'soot_normalized': 0.13457943}
# Raw:  {'pm10': 34.33, 'no2': 22.94, 'so2': 9.1, 'soot': 19.05}
# Transformed:  {'no2_normalized': -9.737978, 'pm10_normalized': 0.10318603, 'so2_normalized': 7.415407, 'soot_normalized': 0.1283817}
# Raw:  {'pm10': 29.67, 'no2': 20.5, 'so2': 8.75, 'soot': 18.89}
# Transformed:  {'no2_normalized': -12.1779785, 'pm10_normalized': 0.08598221, 'so2_normalized': 4.9754066, 'soot_normalized': 0.12680766}
# Raw:  {'pm10': 19.75, 'no2': 20.5, 'so2': 8.45, 'soot': 17.05}
# Transformed:  {'no2_normalized': -12.1779785, 'pm10_normalized': 0.04935947, 'so2_normalized': 4.9754066, 'soot_normalized': 0.10870633}
# Raw:  {'pm10': 28.83, 'no2': 28.81, 'so2': 9.5, 'soot': 28.32}
# Transformed:  {'no2_normalized': -3.867979, 'pm10_normalized': 0.08288109, 'so2_normalized': 13.285406, 'soot_normalized': 0.21957697}
# Raw:  {'pm10': 39.0, 'no2': 28.13, 'so2': 11.3, 'soot': 27.16}
# Transformed:  {'no2_normalized': -4.5479794, 'pm10_normalized': 0.120426774, 'so2_normalized': 12.605406, 'soot_normalized': 0.20816527}
# Raw:  {'pm10': 24.5, 'no2': 18.38, 'so2': 8.85, 'soot': 13.47}
# Transformed:  {'no2_normalized': -14.297979, 'pm10_normalized': 0.06689556, 'so2_normalized': 2.8554058, 'soot_normalized': 0.07348746}
# Raw:  {'pm10': 23.33, 'no2': 17.75, 'so2': 7.55, 'soot': 14.42}
# Transformed:  {'no2_normalized': -14.9279785, 'pm10_normalized': 0.062576145, 'so2_normalized': 2.2254066, 'soot_normalized': 0.08283325}
# Raw:  {'pm10': 24.2, 'no2': 19.38, 'so2': 9.55, 'soot': 16.95}
# Transformed:  {'no2_normalized': -13.297979, 'pm10_normalized': 0.065788016, 'so2_normalized': 3.8554058, 'soot_normalized': 0.10772258}
# Raw:  {'pm10': 24.2, 'no2': 23.93, 'so2': 9.05, 'soot': 22.95}
# Transformed:  {'no2_normalized': -8.747978, 'pm10_normalized': 0.065788016, 'so2_normalized': 8.405407, 'soot_normalized': 0.16674866}
# Raw:  {'pm10': 17.6, 'no2': 21.2, 'so2': 8.85, 'soot': 19.26}
# Transformed:  {'no2_normalized': -11.477978, 'pm10_normalized': 0.041422088, 'so2_normalized': 5.6754074, 'soot_normalized': 0.13044761}
# Raw:  {'pm10': 28.0, 'no2': 15.5, 'so2': 7.9, 'soot': 18.63}
# Transformed:  {'no2_normalized': -17.177979, 'pm10_normalized': 0.079816885, 'so2_normalized': -0.024593353, 'soot_normalized': 0.12424987}
# Raw:  {'pm10': 25.67, 'no2': 11.69, 'so2': 7.85, 'soot': 16.68}
# Transformed:  {'no2_normalized': -20.98798, 'pm10_normalized': 0.07121498, 'so2_normalized': -3.8345938, 'soot_normalized': 0.105066404}
# Raw:  {'pm10': 37.0, 'no2': 19.94, 'so2': 9.3, 'soot': 21.74}
# Transformed:  {'no2_normalized': -12.737978, 'pm10_normalized': 0.11304315, 'so2_normalized': 4.415407, 'soot_normalized': 0.15484506}
# Raw:  {'pm10': 33.67, 'no2': 22.75, 'so2': 10.1, 'soot': 24.89}
# Transformed:  {'no2_normalized': -9.9279785, 'pm10_normalized': 0.100749426, 'so2_normalized': 7.2254066, 'soot_normalized': 0.18583374}
# Raw:  {'pm10': 25.17, 'no2': 18.44, 'so2': 8.6, 'soot': 20.05}
# Transformed:  {'no2_normalized': -14.237978, 'pm10_normalized': 0.06936908, 'so2_normalized': 2.9154072, 'soot_normalized': 0.13821937}
# Raw:  {'pm10': 22.0, 'no2': 21.0, 'so2': 8.8, 'soot': 21.05}
# Transformed:  {'no2_normalized': -11.6779785, 'pm10_normalized': 0.05766604, 'so2_normalized': 5.4754066, 'soot_normalized': 0.14805704}
# Raw:  {'pm10': 23.0, 'no2': 21.75, 'so2': 8.5, 'soot': 21.74}
# Transformed:  {'no2_normalized': -10.9279785, 'pm10_normalized': 0.061357845, 'so2_normalized': 6.2254066, 'soot_normalized': 0.15484506}
# Raw:  {'pm10': 26.67, 'no2': 29.63, 'so2': 10.85, 'soot': 30.63}
# Transformed:  {'no2_normalized': -3.0479794, 'pm10_normalized': 0.07490679, 'so2_normalized': 14.105406, 'soot_normalized': 0.242302}
# Raw:  {'pm10': 35.75, 'no2': 33.25, 'so2': 13.4, 'soot': 37.0}
# Transformed:  {'no2_normalized': 0.5720215, 'pm10_normalized': 0.1084284, 'so2_normalized': 17.725407, 'soot_normalized': 0.30496803}
# Raw:  {'pm10': 31.0, 'no2': 30.13, 'so2': 11.55, 'soot': 30.42}
# Transformed:  {'no2_normalized': -2.5479794, 'pm10_normalized': 0.09089231, 'so2_normalized': 14.605406, 'soot_normalized': 0.2402361}
# Raw:  {'pm10': 36.5, 'no2': 30.31, 'so2': 17.4, 'soot': 27.63}
# Transformed:  {'no2_normalized': -2.367979, 'pm10_normalized': 0.11119725, 'so2_normalized': 14.785406, 'soot_normalized': 0.21278897}
# Raw:  {'pm10': 31.5, 'no2': 26.13, 'so2': 10.65, 'soot': 22.37}
# Transformed:  {'no2_normalized': -6.5479794, 'pm10_normalized': 0.09273821, 'so2_normalized': 10.605406, 'soot_normalized': 0.1610428}
# Raw:  {'pm10': 20.17, 'no2': 17.25, 'so2': 9.1, 'soot': 18.21}
# Transformed:  {'no2_normalized': -15.4279785, 'pm10_normalized': 0.05091003, 'so2_normalized': 1.7254066, 'soot_normalized': 0.120118044}
# Raw:  {'pm10': 32.5, 'no2': 22.44, 'so2': 9.35, 'soot': 22.95}
# Transformed:  {'no2_normalized': -10.237978, 'pm10_normalized': 0.09643002, 'so2_normalized': 6.915407, 'soot_normalized': 0.16674866}
# Raw:  {'pm10': 47.67, 'no2': 29.81, 'so2': 12.95, 'soot': 28.84}
# Transformed:  {'no2_normalized': -2.867979, 'pm10_normalized': 0.15243474, 'so2_normalized': 14.285406, 'soot_normalized': 0.22469257}
# Raw:  {'pm10': 40.17, 'no2': 28.81, 'so2': 13.3, 'soot': 25.42}
# Transformed:  {'no2_normalized': -3.867979, 'pm10_normalized': 0.12474618, 'so2_normalized': 13.285406, 'soot_normalized': 0.19104771}
# Raw:  {'pm10': 44.17, 'no2': 27.06, 'so2': 11.9, 'soot': 25.37}
# Transformed:  {'no2_normalized': -5.617979, 'pm10_normalized': 0.13951342, 'so2_normalized': 11.535406, 'soot_normalized': 0.19055584}
# Raw:  {'pm10': 38.17, 'no2': 25.19, 'so2': 11.8, 'soot': 23.32}
# Transformed:  {'no2_normalized': -7.487978, 'pm10_normalized': 0.11736257, 'so2_normalized': 9.665407, 'soot_normalized': 0.17038858}
# Raw:  {'pm10': 34.17, 'no2': 19.07, 'so2': 10.25, 'soot': 21.11}
# Transformed:  {'no2_normalized': -13.607979, 'pm10_normalized': 0.10259533, 'so2_normalized': 3.5454063, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 31.17, 'no2': 16.4, 'so2': 9.45, 'soot': 16.94}
# Transformed:  {'no2_normalized': -16.277979, 'pm10_normalized': 0.09151992, 'so2_normalized': 0.87540627, 'soot_normalized': 0.1076242}
# Raw:  {'pm10': 35.67, 'no2': 25.67, 'so2': 10.0, 'soot': 20.78}
# Transformed:  {'no2_normalized': -7.0079784, 'pm10_normalized': 0.10813304, 'so2_normalized': 10.145407, 'soot_normalized': 0.1454009}
# Raw:  {'pm10': 43.17, 'no2': 34.6, 'so2': 13.5, 'soot': 27.78}
# Transformed:  {'no2_normalized': 1.92202, 'pm10_normalized': 0.13582161, 'so2_normalized': 19.075405, 'soot_normalized': 0.21426463}
# Raw:  {'pm10': 23.67, 'no2': 23.27, 'so2': 9.75, 'soot': 16.89}
# Transformed:  {'no2_normalized': -9.407978, 'pm10_normalized': 0.06383136, 'so2_normalized': 7.745407, 'soot_normalized': 0.10713231}
# Raw:  {'pm10': 29.5, 'no2': 25.0, 'so2': 10.45, 'soot': 23.72}
# Transformed:  {'no2_normalized': -7.6779785, 'pm10_normalized': 0.0853546, 'so2_normalized': 9.475407, 'soot_normalized': 0.17432365}
# Raw:  {'pm10': 39.17, 'no2': 30.6, 'so2': 10.4, 'soot': 25.89}
# Transformed:  {'no2_normalized': -2.0779781, 'pm10_normalized': 0.12105437, 'so2_normalized': 15.075407, 'soot_normalized': 0.19567141}
# Raw:  {'pm10': 35.0, 'no2': 29.07, 'so2': 11.55, 'soot': 22.16}
# Transformed:  {'no2_normalized': -3.6079788, 'pm10_normalized': 0.10565954, 'so2_normalized': 13.545406, 'soot_normalized': 0.15897688}
# Raw:  {'pm10': 28.0, 'no2': 20.33, 'so2': 9.55, 'soot': 17.42}
# Transformed:  {'no2_normalized': -12.347979, 'pm10_normalized': 0.079816885, 'so2_normalized': 4.8054066, 'soot_normalized': 0.112346284}
# Raw:  {'pm10': 20.5, 'no2': 18.0, 'so2': 8.9, 'soot': 16.33}
# Transformed:  {'no2_normalized': -14.6779785, 'pm10_normalized': 0.052128326, 'so2_normalized': 2.4754066, 'soot_normalized': 0.101623215}
# Raw:  {'pm10': 21.17, 'no2': 19.47, 'so2': 9.45, 'soot': 17.11}
# Transformed:  {'no2_normalized': -13.207979, 'pm10_normalized': 0.05460184, 'so2_normalized': 3.945406, 'soot_normalized': 0.10929661}
# Raw:  {'pm10': 23.33, 'no2': 17.67, 'so2': 9.7, 'soot': 17.61}
# Transformed:  {'no2_normalized': -15.007978, 'pm10_normalized': 0.062576145, 'so2_normalized': 2.1454067, 'soot_normalized': 0.11421545}
# Raw:  {'pm10': 28.33, 'no2': 19.73, 'so2': 10.5, 'soot': 17.67}
# Transformed:  {'no2_normalized': -12.947979, 'pm10_normalized': 0.08103519, 'so2_normalized': 4.205406, 'soot_normalized': 0.114805706}
# Raw:  {'pm10': 28.5, 'no2': 22.33, 'so2': 9.1, 'soot': 16.42}
# Transformed:  {'no2_normalized': -10.347979, 'pm10_normalized': 0.08166279, 'so2_normalized': 6.8054066, 'soot_normalized': 0.102508605}
# Raw:  {'pm10': 21.67, 'no2': 23.25, 'so2': 9.15, 'soot': 15.79}
# Transformed:  {'no2_normalized': -9.4279785, 'pm10_normalized': 0.056447744, 'so2_normalized': 7.7254066, 'soot_normalized': 0.09631087}
# Raw:  {'pm10': 26.17, 'no2': 23.87, 'so2': 9.7, 'soot': 17.21}
# Transformed:  {'no2_normalized': -8.807978, 'pm10_normalized': 0.073060885, 'so2_normalized': 8.3454075, 'soot_normalized': 0.110280365}
# Raw:  {'pm10': 25.67, 'no2': 24.56, 'so2': 10.0, 'soot': 20.21}
# Transformed:  {'no2_normalized': -8.117979, 'pm10_normalized': 0.07121498, 'so2_normalized': 9.035406, 'soot_normalized': 0.1397934}
# Raw:  {'pm10': 23.67, 'no2': 26.5, 'so2': 9.35, 'soot': 17.26}
# Transformed:  {'no2_normalized': -6.1779785, 'pm10_normalized': 0.06383136, 'so2_normalized': 10.975407, 'soot_normalized': 0.11077226}
# Raw:  {'pm10': 24.17, 'no2': 25.0, 'so2': 9.3, 'soot': 20.42}
# Transformed:  {'no2_normalized': -7.6779785, 'pm10_normalized': 0.06567727, 'so2_normalized': 9.475407, 'soot_normalized': 0.14185932}
# Raw:  {'pm10': 27.5, 'no2': 24.5, 'so2': 9.75, 'soot': 14.89}
# Transformed:  {'no2_normalized': -8.1779785, 'pm10_normalized': 0.07797098, 'so2_normalized': 8.975407, 'soot_normalized': 0.087456964}
# Raw:  {'pm10': 25.83, 'no2': 25.27, 'so2': 9.85, 'soot': 23.95}
# Transformed:  {'no2_normalized': -7.407978, 'pm10_normalized': 0.07180567, 'so2_normalized': 9.745407, 'soot_normalized': 0.17658633}
# Raw:  {'pm10': 38.5, 'no2': 29.94, 'so2': 11.9, 'soot': 25.16}
# Transformed:  {'no2_normalized': -2.737978, 'pm10_normalized': 0.11858087, 'so2_normalized': 14.415407, 'soot_normalized': 0.18848991}
# Raw:  {'pm10': 31.83, 'no2': 26.38, 'so2': 10.85, 'soot': 20.79}
# Transformed:  {'no2_normalized': -6.2979794, 'pm10_normalized': 0.093956515, 'so2_normalized': 10.855406, 'soot_normalized': 0.14549927}
# Raw:  {'pm10': 30.8, 'no2': 20.69, 'so2': 9.6, 'soot': 16.11}
# Transformed:  {'no2_normalized': -11.987978, 'pm10_normalized': 0.09015394, 'so2_normalized': 5.165407, 'soot_normalized': 0.09945893}
# Raw:  {'pm10': 18.5, 'no2': 21.69, 'so2': 9.95, 'soot': 17.79}
# Transformed:  {'no2_normalized': -10.987978, 'pm10_normalized': 0.04474471, 'so2_normalized': 6.165407, 'soot_normalized': 0.115986235}
# Raw:  {'pm10': 24.5, 'no2': 24.75, 'so2': 10.45, 'soot': 20.32}
# Transformed:  {'no2_normalized': -7.9279785, 'pm10_normalized': 0.06689556, 'so2_normalized': 9.225407, 'soot_normalized': 0.14087555}
# Raw:  {'pm10': 23.67, 'no2': 27.88, 'so2': 11.75, 'soot': 22.53}
# Transformed:  {'no2_normalized': -4.7979794, 'pm10_normalized': 0.06383136, 'so2_normalized': 12.355406, 'soot_normalized': 0.16261683}
# Raw:  {'pm10': 25.67, 'no2': 29.0, 'so2': 12.4, 'soot': 20.89}
# Transformed:  {'no2_normalized': -3.6779785, 'pm10_normalized': 0.07121498, 'so2_normalized': 13.475407, 'soot_normalized': 0.14648302}
# Raw:  {'pm10': 25.5, 'no2': 26.94, 'so2': 12.65, 'soot': 21.11}
# Transformed:  {'no2_normalized': -5.737978, 'pm10_normalized': 0.07058737, 'so2_normalized': 11.415407, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 16.67, 'no2': 23.5, 'so2': 10.75, 'soot': 19.11}
# Transformed:  {'no2_normalized': -9.1779785, 'pm10_normalized': 0.037988704, 'so2_normalized': 7.9754066, 'soot_normalized': 0.12897196}
# Raw:  {'pm10': 31.5, 'no2': 28.31, 'so2': 12.7, 'soot': 19.44}
# Transformed:  {'no2_normalized': -4.367979, 'pm10_normalized': 0.09273821, 'so2_normalized': 12.785406, 'soot_normalized': 0.1322184}
# Raw:  {'pm10': 31.67, 'no2': 25.73, 'so2': 10.85, 'soot': 19.65}
# Transformed:  {'no2_normalized': -6.947979, 'pm10_normalized': 0.093365826, 'so2_normalized': 10.205406, 'soot_normalized': 0.1342843}
# Raw:  {'pm10': 26.67, 'no2': 20.07, 'so2': 9.2, 'soot': 18.0}
# Transformed:  {'no2_normalized': -12.607979, 'pm10_normalized': 0.07490679, 'so2_normalized': 4.5454063, 'soot_normalized': 0.11805214}
# Raw:  {'pm10': 10.0, 'no2': 19.87, 'so2': 9.65, 'soot': 16.41}
# Transformed:  {'no2_normalized': -12.807978, 'pm10_normalized': 0.013364344, 'so2_normalized': 4.3454075, 'soot_normalized': 0.10241023}
# Raw:  {'pm10': 11.83, 'no2': 20.73, 'so2': 9.8, 'soot': 18.56}
# Transformed:  {'no2_normalized': -11.947979, 'pm10_normalized': 0.020120353, 'so2_normalized': 5.205406, 'soot_normalized': 0.12356123}
# Raw:  {'pm10': 23.67, 'no2': 25.0, 'so2': 11.9, 'soot': 17.67}
# Transformed:  {'no2_normalized': -7.6779785, 'pm10_normalized': 0.06383136, 'so2_normalized': 9.475407, 'soot_normalized': 0.114805706}
# Raw:  {'pm10': 20.33, 'no2': 24.33, 'so2': 10.85, 'soot': 16.72}
# Transformed:  {'no2_normalized': -8.347979, 'pm10_normalized': 0.05150072, 'so2_normalized': 8.805407, 'soot_normalized': 0.105459906}
# Raw:  {'pm10': 18.67, 'no2': 21.73, 'so2': 11.0, 'soot': 13.61}
# Transformed:  {'no2_normalized': -10.947979, 'pm10_normalized': 0.04537232, 'so2_normalized': 6.205406, 'soot_normalized': 0.07486473}
# Raw:  {'pm10': 20.33, 'no2': 22.87, 'so2': 11.5, 'soot': 18.78}
# Transformed:  {'no2_normalized': -9.807978, 'pm10_normalized': 0.05150072, 'so2_normalized': 7.3454075, 'soot_normalized': 0.12572554}
# Raw:  {'pm10': 32.5, 'no2': 22.0, 'so2': 10.45, 'soot': 20.0}
# Transformed:  {'no2_normalized': -10.6779785, 'pm10_normalized': 0.09643002, 'so2_normalized': 6.4754066, 'soot_normalized': 0.1377275}
# Raw:  {'pm10': 33.25, 'no2': 24.93, 'so2': 10.8, 'soot': 22.56}
# Transformed:  {'no2_normalized': -7.747978, 'pm10_normalized': 0.09919888, 'so2_normalized': 9.405407, 'soot_normalized': 0.16291195}
# Raw:  {'pm10': 26.5, 'no2': 22.6, 'so2': 10.5, 'soot': 19.11}
# Transformed:  {'no2_normalized': -10.077978, 'pm10_normalized': 0.074279174, 'so2_normalized': 7.075407, 'soot_normalized': 0.12897196}
# Raw:  {'pm10': 29.25, 'no2': 26.6, 'so2': 10.3, 'soot': 23.28}
# Transformed:  {'no2_normalized': -6.077978, 'pm10_normalized': 0.08443164, 'so2_normalized': 11.075407, 'soot_normalized': 0.16999508}
# Raw:  {'pm10': 33.9, 'no2': 25.69, 'so2': 10.28, 'soot': 26.33}
# Transformed:  {'no2_normalized': -6.987978, 'pm10_normalized': 0.10159855, 'so2_normalized': 10.165407, 'soot_normalized': 0.2}
# Raw:  {'pm10': 40.03, 'no2': 28.76, 'so2': 10.28, 'soot': 29.17}
# Transformed:  {'no2_normalized': -3.9179783, 'pm10_normalized': 0.12422933, 'so2_normalized': 13.235407, 'soot_normalized': 0.22793901}
# Raw:  {'pm10': 38.77, 'no2': 28.01, 'so2': 10.72, 'soot': 23.17}
# Transformed:  {'no2_normalized': -4.6679783, 'pm10_normalized': 0.11957765, 'so2_normalized': 12.485407, 'soot_normalized': 0.16891293}
# Raw:  {'pm10': 33.68, 'no2': 21.45, 'so2': 9.28, 'soot': 19.89}
# Transformed:  {'no2_normalized': -11.227978, 'pm10_normalized': 0.10078635, 'so2_normalized': 5.9254074, 'soot_normalized': 0.13664535}
# Raw:  {'pm10': 26.18, 'no2': 18.79, 'so2': 9.35, 'soot': 16.83}
# Transformed:  {'no2_normalized': -13.887978, 'pm10_normalized': 0.073097795, 'so2_normalized': 3.2654076, 'soot_normalized': 0.10654205}
# Raw:  {'pm10': 31.15, 'no2': 28.15, 'so2': 9.67, 'soot': 25.11}
# Transformed:  {'no2_normalized': -4.527979, 'pm10_normalized': 0.09144609, 'so2_normalized': 12.625406, 'soot_normalized': 0.18799804}
# Raw:  {'pm10': 32.42, 'no2': 26.43, 'so2': 11.57, 'soot': 23.28}
# Transformed:  {'no2_normalized': -6.247978, 'pm10_normalized': 0.09613467, 'so2_normalized': 10.905407, 'soot_normalized': 0.16999508}
# Raw:  {'pm10': 24.1, 'no2': 23.91, 'so2': 9.83, 'soot': 17.06}
# Transformed:  {'no2_normalized': -8.767979, 'pm10_normalized': 0.06541884, 'so2_normalized': 8.3854065, 'soot_normalized': 0.10880472}
# Raw:  {'pm10': 21.87, 'no2': 24.86, 'so2': 9.44, 'soot': 25.06}
# Transformed:  {'no2_normalized': -7.817978, 'pm10_normalized': 0.057186108, 'so2_normalized': 9.335407, 'soot_normalized': 0.18750614}
# Raw:  {'pm10': 25.8, 'no2': 24.5, 'so2': 10.49, 'soot': 19.95}
# Transformed:  {'no2_normalized': -8.1779785, 'pm10_normalized': 0.0716949, 'so2_normalized': 8.975407, 'soot_normalized': 0.13723561}
# Raw:  {'pm10': 15.02, 'no2': 18.2, 'so2': 9.03, 'soot': 13.16}
# Transformed:  {'no2_normalized': -14.477978, 'pm10_normalized': 0.03189722, 'so2_normalized': 2.6754074, 'soot_normalized': 0.070437774}
# Raw:  {'pm10': 16.43, 'no2': 17.79, 'so2': 9.07, 'soot': 16.21}
# Transformed:  {'no2_normalized': -14.887978, 'pm10_normalized': 0.03710267, 'so2_normalized': 2.2654076, 'soot_normalized': 0.100442685}
# Raw:  {'pm10': 23.88, 'no2': 25.64, 'so2': 10.05, 'soot': 21.84}
# Transformed:  {'no2_normalized': -7.037979, 'pm10_normalized': 0.06460664, 'so2_normalized': 10.115406, 'soot_normalized': 0.15582882}
# Raw:  {'pm10': 32.32, 'no2': 28.14, 'so2': 10.79, 'soot': 23.05}
# Transformed:  {'no2_normalized': -4.537979, 'pm10_normalized': 0.095765494, 'so2_normalized': 12.615406, 'soot_normalized': 0.1677324}
# Raw:  {'pm10': 43.03, 'no2': 27.55, 'so2': 12.89, 'soot': 28.28}
# Transformed:  {'no2_normalized': -5.1279793, 'pm10_normalized': 0.13530475, 'so2_normalized': 12.025406, 'soot_normalized': 0.21918347}
# Raw:  {'pm10': 45.87, 'no2': 31.64, 'so2': 12.04, 'soot': 23.56}
# Transformed:  {'no2_normalized': -1.0379791, 'pm10_normalized': 0.14578949, 'so2_normalized': 16.115406, 'soot_normalized': 0.17274962}
# Raw:  {'pm10': 40.35, 'no2': 27.91, 'so2': 11.48, 'soot': 19.67}
# Transformed:  {'no2_normalized': -4.7679787, 'pm10_normalized': 0.1254107, 'so2_normalized': 12.3854065, 'soot_normalized': 0.13448106}
# Raw:  {'pm10': 43.2, 'no2': 21.54, 'so2': 10.99, 'soot': 12.17}
# Transformed:  {'no2_normalized': -11.137978, 'pm10_normalized': 0.13593237, 'so2_normalized': 6.0154076, 'soot_normalized': 0.060698476}
# Raw:  {'pm10': 30.17, 'no2': 19.47, 'so2': 9.78, 'soot': 12.44}
# Transformed:  {'no2_normalized': -13.207979, 'pm10_normalized': 0.087828115, 'so2_normalized': 3.945406, 'soot_normalized': 0.06335464}
# Raw:  {'pm10': 24.0, 'no2': 24.83, 'so2': 10.55, 'soot': 22.67}
# Transformed:  {'no2_normalized': -7.8479786, 'pm10_normalized': 0.065049656, 'so2_normalized': 9.305407, 'soot_normalized': 0.16399409}
# Raw:  {'pm10': 28.35, 'no2': 27.93, 'so2': 8.18, 'soot': 22.72}
# Transformed:  {'no2_normalized': -4.747978, 'pm10_normalized': 0.081109025, 'so2_normalized': 12.405407, 'soot_normalized': 0.16448598}
# Raw:  {'pm10': 25.25, 'no2': 29.63, 'so2': 7.72, 'soot': 22.33}
# Transformed:  {'no2_normalized': -3.0479794, 'pm10_normalized': 0.06966441, 'so2_normalized': 14.105406, 'soot_normalized': 0.16064928}
# Raw:  {'pm10': 33.55, 'no2': 36.37, 'so2': 8.21, 'soot': 29.5}
# Transformed:  {'no2_normalized': 3.6920204, 'pm10_normalized': 0.100306414, 'so2_normalized': 20.845406, 'soot_normalized': 0.23118544}
# Raw:  {'pm10': 33.93, 'no2': 30.72, 'so2': 6.63, 'soot': 24.5}
# Transformed:  {'no2_normalized': -1.9579792, 'pm10_normalized': 0.101709306, 'so2_normalized': 15.195406, 'soot_normalized': 0.18199705}
# Raw:  {'pm10': 23.38, 'no2': 25.5, 'so2': 7.87, 'soot': 18.72}
# Transformed:  {'no2_normalized': -7.1779785, 'pm10_normalized': 0.06276073, 'so2_normalized': 9.975407, 'soot_normalized': 0.12513526}
# Raw:  {'pm10': 15.58, 'no2': 18.33, 'so2': 7.1, 'soot': 16.28}
# Transformed:  {'no2_normalized': -14.347979, 'pm10_normalized': 0.033964634, 'so2_normalized': 2.8054066, 'soot_normalized': 0.101131335}
# Raw:  {'pm10': 27.6, 'no2': 28.78, 'so2': 7.62, 'soot': 20.94}
# Transformed:  {'no2_normalized': -3.8979778, 'pm10_normalized': 0.07834017, 'so2_normalized': 13.255407, 'soot_normalized': 0.14697492}
# Raw:  {'pm10': 32.57, 'no2': 31.81, 'so2': 7.66, 'soot': 25.11}
# Transformed:  {'no2_normalized': -0.86797905, 'pm10_normalized': 0.09668844, 'so2_normalized': 16.285406, 'soot_normalized': 0.18799804}
# Raw:  {'pm10': 29.1, 'no2': 32.51, 'so2': 8.18, 'soot': 26.72}
# Transformed:  {'no2_normalized': -0.1679802, 'pm10_normalized': 0.083877884, 'so2_normalized': 16.985405, 'soot_normalized': 0.20383668}
# Raw:  {'pm10': 31.2, 'no2': 39.67, 'so2': 7.92, 'soot': 28.94}
# Transformed:  {'no2_normalized': 6.9920197, 'pm10_normalized': 0.091630675, 'so2_normalized': 24.145405, 'soot_normalized': 0.22567634}
# Raw:  {'pm10': 29.78, 'no2': 41.39, 'so2': 9.16, 'soot': 27.59}
# Transformed:  {'no2_normalized': 8.712021, 'pm10_normalized': 0.08638831, 'so2_normalized': 25.865406, 'soot_normalized': 0.21239547}
# Raw:  {'pm10': 36.02, 'no2': 33.29, 'so2': 6.11, 'soot': 27.28}
# Transformed:  {'no2_normalized': 0.6120224, 'pm10_normalized': 0.10942519, 'so2_normalized': 17.765408, 'soot_normalized': 0.2093458}
# Raw:  {'pm10': 40.15, 'no2': 24.14, 'so2': 6.5, 'soot': 19.61}
# Transformed:  {'no2_normalized': -8.537979, 'pm10_normalized': 0.12467235, 'so2_normalized': 8.615406, 'soot_normalized': 0.13389081}
# Raw:  {'pm10': 33.95, 'no2': 32.85, 'so2': 7.11, 'soot': 23.53}
# Transformed:  {'no2_normalized': 0.17201996, 'pm10_normalized': 0.10178314, 'so2_normalized': 17.325405, 'soot_normalized': 0.1724545}
# Raw:  {'pm10': 33.63, 'no2': 35.14, 'so2': 6.49, 'soot': 26.44}
# Transformed:  {'no2_normalized': 2.4620209, 'pm10_normalized': 0.10060177, 'so2_normalized': 19.615406, 'soot_normalized': 0.20108214}
# Raw:  {'pm10': 18.25, 'no2': 29.13, 'so2': 5.71, 'soot': 21.0}
# Transformed:  {'no2_normalized': -3.5479794, 'pm10_normalized': 0.04382176, 'so2_normalized': 13.605406, 'soot_normalized': 0.14756517}
# Raw:  {'pm10': 20.12, 'no2': 26.85, 'so2': 5.39, 'soot': 19.32}
# Transformed:  {'no2_normalized': -5.827978, 'pm10_normalized': 0.050725445, 'so2_normalized': 11.325407, 'soot_normalized': 0.13103788}
# Raw:  {'pm10': 22.6, 'no2': 27.75, 'so2': 5.95, 'soot': 16.84}
# Transformed:  {'no2_normalized': -4.9279785, 'pm10_normalized': 0.05988113, 'so2_normalized': 12.225407, 'soot_normalized': 0.106640436}
# Raw:  {'pm10': 43.65, 'no2': 28.93, 'so2': 6.85, 'soot': 20.84}
# Transformed:  {'no2_normalized': -3.7479782, 'pm10_normalized': 0.13759369, 'so2_normalized': 13.405407, 'soot_normalized': 0.14599115}
# Raw:  {'pm10': 37.55, 'no2': 29.46, 'so2': 5.92, 'soot': 23.74}
# Transformed:  {'no2_normalized': -3.2179794, 'pm10_normalized': 0.11507364, 'so2_normalized': 13.935406, 'soot_normalized': 0.1745204}
# Raw:  {'pm10': 32.33, 'no2': 25.63, 'so2': 7.3, 'soot': 21.05}
# Transformed:  {'no2_normalized': -7.0479794, 'pm10_normalized': 0.09580242, 'so2_normalized': 10.105406, 'soot_normalized': 0.14805704}
# Raw:  {'pm10': 30.88, 'no2': 26.13, 'so2': 7.29, 'soot': 20.89}
# Transformed:  {'no2_normalized': -6.5479794, 'pm10_normalized': 0.090449296, 'so2_normalized': 10.605406, 'soot_normalized': 0.14648302}
# Raw:  {'pm10': 29.8, 'no2': 28.1, 'so2': 5.51, 'soot': 21.11}
# Transformed:  {'no2_normalized': -4.577978, 'pm10_normalized': 0.08646213, 'so2_normalized': 12.575407, 'soot_normalized': 0.14864732}
# Raw:  {'pm10': 24.65, 'no2': 32.67, 'so2': 7.27, 'soot': 26.33}
# Transformed:  {'no2_normalized': -0.007980347, 'pm10_normalized': 0.06744933, 'so2_normalized': 17.145405, 'soot_normalized': 0.2}
# Raw:  {'pm10': 29.55, 'no2': 29.96, 'so2': 7.25, 'soot': 30.67}
# ...
# Raw:  {'pm10': 34.17, 'no2': 27.51, 'so2': 12.44, 'soot': 15.29}
# Transformed:  {'no2_normalized': -5.1679783, 'pm10_normalized': 0.10259533, 'so2_normalized': 11.985407, 'soot_normalized': 0.09139203}
# Raw:  {'pm10': 32.9, 'no2': 30.44, 'so2': 12.0, 'soot': 13.99}
# Transformed:  {'no2_normalized': -2.237978, 'pm10_normalized': 0.097906746, 'so2_normalized': 14.915407, 'soot_normalized': 0.078603044}
# Raw:  {'pm10': 53.7, 'no2': 40.64, 'so2': 16.37, 'soot': 21.64}
# Transformed:  {'no2_normalized': 7.962021, 'pm10_normalized': 0.17469636, 'so2_normalized': 25.115406, 'soot_normalized': 0.15386128}
# Raw:  {'pm10': 74.78, 'no2': 50.49, 'so2': 13.68, 'soot': 28.34}
# Transformed:  {'no2_normalized': 17.812023, 'pm10_normalized': 0.25251967, 'so2_normalized': 34.96541, 'soot_normalized': 0.21977372}
# Raw:  {'pm10': 57.13, 'no2': 52.83, 'so2': 14.17, 'soot': 23.18}
# Transformed:  {'no2_normalized': 20.152023, 'pm10_normalized': 0.18735926, 'so2_normalized': 37.30541, 'soot_normalized': 0.16901131}
# Raw:  {'pm10': 53.88, 'no2': 49.65, 'so2': 12.7, 'soot': 21.81}
# Transformed:  {'no2_normalized': 16.972023, 'pm10_normalized': 0.17536087, 'so2_normalized': 34.12541, 'soot_normalized': 0.15553369}
# Raw:  {'pm10': 33.63, 'no2': 37.85, 'so2': 12.58, 'soot': 18.28}
# Transformed:  {'no2_normalized': 5.17202, 'pm10_normalized': 0.10060177, 'so2_normalized': 22.325405, 'soot_normalized': 0.120806694}
# Raw:  {'pm10': 40.23, 'no2': 43.25, 'so2': 12.56, 'soot': 20.93}
# Transformed:  {'no2_normalized': 10.5720215, 'pm10_normalized': 0.124967694, 'so2_normalized': 27.725407, 'soot_normalized': 0.14687654}
# Raw:  {'pm10': 27.85, 'no2': 39.97, 'so2': 12.31, 'soot': 16.56}
# Transformed:  {'no2_normalized': 7.2920227, 'pm10_normalized': 0.07926312, 'so2_normalized': 24.445408, 'soot_normalized': 0.103885874}
# Raw:  {'pm10': 41.93, 'no2': 38.29, 'so2': 14.06, 'soot': 17.41}
# Transformed:  {'no2_normalized': 5.6120224, 'pm10_normalized': 0.13124377, 'so2_normalized': 22.765408, 'soot_normalized': 0.11224791}
# Raw:  {'pm10': 47.85, 'no2': 48.91, 'so2': 15.48, 'soot': 22.3}
# Transformed:  {'no2_normalized': 16.232021, 'pm10_normalized': 0.15309927, 'so2_normalized': 33.385406, 'soot_normalized': 0.16035415}
# Raw:  {'pm10': 54.2, 'no2': 53.99, 'so2': 15.39, 'soot': 19.85}
# Transformed:  {'no2_normalized': 21.312023, 'pm10_normalized': 0.17654225, 'so2_normalized': 38.46541, 'soot_normalized': 0.13625185}
# Raw:  {'pm10': 25.95, 'no2': 36.62, 'so2': 10.09, 'soot': 13.38}
# Transformed:  {'no2_normalized': 3.9420204, 'pm10_normalized': 0.07224868, 'so2_normalized': 21.095406, 'soot_normalized': 0.07260206}
# Raw:  {'pm10': 21.2, 'no2': 33.32, 'so2': 10.04, 'soot': 14.46}
# Transformed:  {'no2_normalized': 0.6420212, 'pm10_normalized': 0.054712597, 'so2_normalized': 17.795406, 'soot_normalized': 0.083226755}
# Raw:  {'pm10': 25.2, 'no2': 35.54, 'so2': 15.39, 'soot': 14.41}
# Transformed:  {'no2_normalized': 2.8620224, 'pm10_normalized': 0.06947982, 'so2_normalized': 20.015408, 'soot_normalized': 0.082734875}
# Raw:  {'pm10': 21.73, 'no2': 30.34, 'so2': 14.31, 'soot': 15.31}
# Transformed:  {'no2_normalized': -2.3379784, 'pm10_normalized': 0.05666925, 'so2_normalized': 14.815407, 'soot_normalized': 0.09158879}
# Raw:  {'pm10': 19.0, 'no2': 29.7, 'so2': 11.03, 'soot': 13.63}
# Transformed:  {'no2_normalized': -2.9779778, 'pm10_normalized': 0.046590615, 'so2_normalized': 14.175407, 'soot_normalized': 0.075061485}
# Raw:  {'pm10': 38.15, 'no2': 37.31, 'so2': 15.98, 'soot': 17.72}
# Transformed:  {'no2_normalized': 4.632023, 'pm10_normalized': 0.11728874, 'so2_normalized': 21.785408, 'soot_normalized': 0.11529758}
# Raw:  {'pm10': 44.1, 'no2': 39.72, 'so2': 18.52, 'soot': 16.19}
# Transformed:  {'no2_normalized': 7.0420227, 'pm10_normalized': 0.13925499, 'so2_normalized': 24.195408, 'soot_normalized': 0.100245945}
# Raw:  {'pm10': 48.13, 'no2': 34.53, 'so2': 15.38, 'soot': 17.83}
# Transformed:  {'no2_normalized': 1.8520203, 'pm10_normalized': 0.15413298, 'so2_normalized': 19.005405, 'soot_normalized': 0.11637973}
# Raw:  {'pm10': 80.6, 'no2': 35.09, 'so2': 15.05, 'soot': 21.1}
# Transformed:  {'no2_normalized': 2.4120216, 'pm10_normalized': 0.27400598, 'so2_normalized': 19.565407, 'soot_normalized': 0.14854895}
# Raw:  {'pm10': 76.83, 'no2': 48.86, 'so2': 18.59, 'soot': 22.71}
# Transformed:  {'no2_normalized': 16.182022, 'pm10_normalized': 0.26008788, 'so2_normalized': 33.335407, 'soot_normalized': 0.1643876}
# Raw:  {'pm10': 63.58, 'no2': 50.83, 'so2': 18.2, 'soot': 20.75}
# Transformed:  {'no2_normalized': 18.152023, 'pm10_normalized': 0.21117142, 'so2_normalized': 35.30541, 'soot_normalized': 0.14510575}
# Raw:  {'pm10': 76.58, 'no2': 49.24, 'so2': 17.4, 'soot': 24.63}
# Transformed:  {'no2_normalized': 16.562023, 'pm10_normalized': 0.25916493, 'so2_normalized': 33.71541, 'soot_normalized': 0.18327594}
# Raw:  {'pm10': 48.1, 'no2': 33.23, 'so2': 16.24, 'soot': 20.34}
# Transformed:  {'no2_normalized': 0.552021, 'pm10_normalized': 0.15402222, 'so2_normalized': 17.705406, 'soot_normalized': 0.1410723}
# Raw:  {'pm10': 41.7, 'no2': 42.15, 'so2': 12.81, 'soot': 19.26}
# Transformed:  {'no2_normalized': 9.472023, 'pm10_normalized': 0.13039465, 'so2_normalized': 26.625408, 'soot_normalized': 0.13044761}
# Raw:  {'pm10': 39.53, 'no2': 33.64, 'so2': 10.92, 'soot': 16.76}
# Transformed:  {'no2_normalized': 0.9620209, 'pm10_normalized': 0.12238342, 'so2_normalized': 18.115406, 'soot_normalized': 0.105853416}
# Raw:  {'pm10': 43.15, 'no2': 31.27, 'so2': 7.78, 'soot': 16.78}
# Transformed:  {'no2_normalized': -1.407978, 'pm10_normalized': 0.13574778, 'so2_normalized': 15.745407, 'soot_normalized': 0.10605018}
# Raw:  {'pm10': 37.75, 'no2': 35.07, 'so2': 9.93, 'soot': 16.31}
# Transformed:  {'no2_normalized': 2.3920212, 'pm10_normalized': 0.11581201, 'so2_normalized': 19.545406, 'soot_normalized': 0.10142646}
# Raw:  {'pm10': 48.85, 'no2': 35.01, 'so2': 10.1, 'soot': 13.81}
# Transformed:  {'no2_normalized': 2.3320198, 'pm10_normalized': 0.15679108, 'so2_normalized': 19.485405, 'soot_normalized': 0.07683227}
# Raw:  {'pm10': 49.2, 'no2': 42.74, 'so2': 11.7, 'soot': 15.83}
# Transformed:  {'no2_normalized': 10.062023, 'pm10_normalized': 0.15808322, 'so2_normalized': 27.215408, 'soot_normalized': 0.09670438}
# Raw:  {'pm10': 49.65, 'no2': 44.01, 'so2': 12.48, 'soot': 18.78}
# Transformed:  {'no2_normalized': 11.33202, 'pm10_normalized': 0.15974453, 'so2_normalized': 28.485405, 'soot_normalized': 0.12572554}
# Raw:  {'pm10': 35.98, 'no2': 33.62, 'so2': 10.33, 'soot': 17.32}
# Transformed:  {'no2_normalized': 0.9420204, 'pm10_normalized': 0.10927751, 'so2_normalized': 18.095406, 'soot_normalized': 0.11136252}
# Raw:  {'pm10': 31.35, 'no2': 27.43, 'so2': 12.98, 'soot': 16.06}
# Transformed:  {'no2_normalized': -5.247978, 'pm10_normalized': 0.09218445, 'so2_normalized': 11.905407, 'soot_normalized': 0.09896704}
# Raw:  {'pm10': 37.8, 'no2': 28.23, 'so2': 10.92, 'soot': 13.54}
# Transformed:  {'no2_normalized': -4.447979, 'pm10_normalized': 0.1159966, 'so2_normalized': 12.705406, 'soot_normalized': 0.074176095}
# Raw:  {'pm10': 32.88, 'no2': 34.86, 'so2': 11.08, 'soot': 10.47}
# Transformed:  {'no2_normalized': 2.182022, 'pm10_normalized': 0.09783291, 'so2_normalized': 19.335407, 'soot_normalized': 0.043974426}
# Raw:  {'pm10': 30.68, 'no2': 27.07, 'so2': 9.95, 'soot': 11.03}
# Transformed:  {'no2_normalized': -5.607979, 'pm10_normalized': 0.08971093, 'so2_normalized': 11.545406, 'soot_normalized': 0.04948352}
# Raw:  {'pm10': 27.85, 'no2': 23.1, 'so2': 12.35, 'soot': 11.38}
# Transformed:  {'no2_normalized': -9.577978, 'pm10_normalized': 0.07926312, 'so2_normalized': 7.575407, 'soot_normalized': 0.052926708}
# Raw:  {'pm10': 32.95, 'no2': 27.42, 'so2': 12.55, 'soot': 11.92}
# Transformed:  {'no2_normalized': -5.2579784, 'pm10_normalized': 0.098091334, 'so2_normalized': 11.895407, 'soot_normalized': 0.058239054}
# Raw:  {'pm10': 22.08, 'no2': 30.36, 'so2': 12.02, 'soot': 10.5}
# Transformed:  {'no2_normalized': -2.317978, 'pm10_normalized': 0.057961386, 'so2_normalized': 14.835407, 'soot_normalized': 0.04426955}
# Raw:  {'pm10': 32.73, 'no2': 35.57, 'so2': 14.79, 'soot': 12.7}
# Transformed:  {'no2_normalized': 2.8920212, 'pm10_normalized': 0.09727913, 'so2_normalized': 20.045406, 'soot_normalized': 0.06591244}
# Raw:  {'pm10': 28.98, 'no2': 30.92, 'so2': 14.07, 'soot': 13.15}
# Transformed:  {'no2_normalized': -1.7579784, 'pm10_normalized': 0.08343486, 'so2_normalized': 15.395407, 'soot_normalized': 0.0703394}
# Raw:  {'pm10': 42.05, 'no2': 34.51, 'so2': 15.36, 'soot': 13.18}
# Transformed:  {'no2_normalized': 1.8320198, 'pm10_normalized': 0.13168678, 'so2_normalized': 18.985405, 'soot_normalized': 0.07063453}
# Raw:  {'pm10': 58.78, 'no2': 45.75, 'so2': 14.98, 'soot': 22.3}
# Transformed:  {'no2_normalized': 13.0720215, 'pm10_normalized': 0.19345073, 'so2_normalized': 30.225407, 'soot_normalized': 0.16035415}
# Raw:  {'pm10': 63.48, 'no2': 51.06, 'so2': 15.23, 'soot': 25.33}
# Transformed:  {'no2_normalized': 18.382023, 'pm10_normalized': 0.21080223, 'so2_normalized': 35.535408, 'soot_normalized': 0.19016232}
# Raw:  {'pm10': 57.1, 'no2': 42.83, 'so2': 15.44, 'soot': 27.76}
# Transformed:  {'no2_normalized': 10.152023, 'pm10_normalized': 0.18724848, 'so2_normalized': 27.305408, 'soot_normalized': 0.21406788}
# Raw:  {'pm10': 34.05, 'no2': 38.46, 'so2': 13.78, 'soot': 19.68}
# Transformed:  {'no2_normalized': 5.7820206, 'pm10_normalized': 0.10215232, 'so2_normalized': 22.935406, 'soot_normalized': 0.13457943}
# Raw:  {'pm10': 36.8, 'no2': 40.8, 'so2': 13.79, 'soot': 18.8}
# Transformed:  {'no2_normalized': 8.122021, 'pm10_normalized': 0.11230479, 'so2_normalized': 25.275406, 'soot_normalized': 0.12592228}
# Raw:  {'pm10': 35.15, 'no2': 34.6, 'so2': 12.44, 'soot': 18.1}
# Transformed:  {'no2_normalized': 1.92202, 'pm10_normalized': 0.10621332, 'so2_normalized': 19.075405, 'soot_normalized': 0.11903591}
# Raw:  {'pm10': 49.28, 'no2': 39.76, 'so2': 16.46, 'soot': 18.62}
# Transformed:  {'no2_normalized': 7.08202, 'pm10_normalized': 0.15837856, 'so2_normalized': 24.235405, 'soot_normalized': 0.124151506}
# Raw:  {'pm10': 66.23, 'no2': 38.92, 'so2': 15.99, 'soot': 24.0}
# Transformed:  {'no2_normalized': 6.2420197, 'pm10_normalized': 0.22095472, 'so2_normalized': 23.395405, 'soot_normalized': 0.1770782}
# Raw:  {'pm10': 51.9, 'no2': 29.95, 'so2': 12.58, 'soot': 17.11}
# Transformed:  {'no2_normalized': -2.7279778, 'pm10_normalized': 0.1680511, 'so2_normalized': 14.425407, 'soot_normalized': 0.10929661}
# Raw:  {'pm10': 41.4, 'no2': 20.78, 'so2': 16.75, 'soot': 16.29}
# Transformed:  {'no2_normalized': -11.897978, 'pm10_normalized': 0.12928711, 'so2_normalized': 5.2554073, 'soot_normalized': 0.10122972}
# Raw:  {'pm10': 26.83, 'no2': 26.44, 'so2': 15.29, 'soot': 11.27}
# Transformed:  {'no2_normalized': -6.237978, 'pm10_normalized': 0.07549748, 'so2_normalized': 10.915407, 'soot_normalized': 0.051844567}
# Raw:  {'pm10': 22.47, 'no2': 26.38, 'so2': 16.08, 'soot': 8.19}
# Transformed:  {'no2_normalized': -6.2979794, 'pm10_normalized': 0.05940119, 'so2_normalized': 10.855406, 'soot_normalized': 0.02154451}
# Raw:  {'pm10': 17.87, 'no2': 27.9, 'so2': 16.79, 'soot': 9.55}
# Transformed:  {'no2_normalized': -4.777979, 'pm10_normalized': 0.042418875, 'so2_normalized': 12.375406, 'soot_normalized': 0.03492376}
# Raw:  {'pm10': 21.73, 'no2': 27.23, 'so2': 18.79, 'soot': 8.49}
# Transformed:  {'no2_normalized': -5.447979, 'pm10_normalized': 0.05666925, 'so2_normalized': 11.705406, 'soot_normalized': 0.024495816}
# Raw:  {'pm10': 22.07, 'no2': 27.29, 'so2': 14.36, 'soot': 11.04}
# Transformed:  {'no2_normalized': -5.3879776, 'pm10_normalized': 0.057924464, 'so2_normalized': 11.765408, 'soot_normalized': 0.049581897}
# Raw:  {'pm10': 53.3, 'no2': 34.32, 'so2': 15.87, 'soot': 12.51}
# Transformed:  {'no2_normalized': 1.6420212, 'pm10_normalized': 0.17321962, 'so2_normalized': 18.795406, 'soot_normalized': 0.06404328}
# Raw:  {'pm10': 72.27, 'no2': 32.79, 'so2': 19.79, 'soot': 14.8}
# Transformed:  {'no2_normalized': 0.1120224, 'pm10_normalized': 0.24325322, 'so2_normalized': 17.265408, 'soot_normalized': 0.08657157}
# Raw:  {'pm10': 35.07, 'no2': 25.75, 'so2': 15.19, 'soot': 12.5}
# Transformed:  {'no2_normalized': -6.9279785, 'pm10_normalized': 0.10591797, 'so2_normalized': 10.225407, 'soot_normalized': 0.063944906}
# Raw:  {'pm10': 30.7, 'no2': 33.26, 'so2': 14.51, 'soot': 14.18}
# Transformed:  {'no2_normalized': 0.5820198, 'pm10_normalized': 0.08978477, 'so2_normalized': 17.735405, 'soot_normalized': 0.08047221}
# Raw:  {'pm10': 59.2, 'no2': 37.4, 'so2': 27.18, 'soot': 20.77}
# Transformed:  {'no2_normalized': 4.722023, 'pm10_normalized': 0.19500129, 'so2_normalized': 21.875408, 'soot_normalized': 0.1453025}
# Raw:  {'pm10': 89.33, 'no2': 47.61, 'so2': 23.2, 'soot': 25.04}
# Transformed:  {'no2_normalized': 14.932022, 'pm10_normalized': 0.3062355, 'so2_normalized': 32.085407, 'soot_normalized': 0.1873094}
# Raw:  {'pm10': 78.7, 'no2': 55.61, 'so2': 21.38, 'soot': 27.87}
# Transformed:  {'no2_normalized': 22.932022, 'pm10_normalized': 0.26699156, 'so2_normalized': 40.085407, 'soot_normalized': 0.21515003}
# Raw:  {'pm10': 177.1, 'no2': 85.79, 'so2': 23.24, 'soot': 36.75}
# Transformed:  {'no2_normalized': 53.112022, 'pm10_normalized': 0.6302655, 'so2_normalized': 70.26541, 'soot_normalized': 0.3025086}
# Raw:  {'pm10': 190.23, 'no2': 89.32, 'so2': 25.1, 'soot': 34.97}
# Transformed:  {'no2_normalized': 56.64202, 'pm10_normalized': 0.67873883, 'so2_normalized': 73.79541, 'soot_normalized': 0.28499755}
# Raw:  {'pm10': 142.83, 'no2': 58.59, 'so2': 21.36, 'soot': 23.35}
# Transformed:  {'no2_normalized': 25.912022, 'pm10_normalized': 0.50374717, 'so2_normalized': 43.065407, 'soot_normalized': 0.17068373}
# Raw:  {'pm10': 88.77, 'no2': 42.78, 'so2': 19.86, 'soot': 23.85}
# Transformed:  {'no2_normalized': 10.10202, 'pm10_normalized': 0.30416805, 'so2_normalized': 27.255405, 'soot_normalized': 0.17560256}
# Raw:  {'pm10': 63.73, 'no2': 52.96, 'so2': 19.28, 'soot': 26.09}
# Transformed:  {'no2_normalized': 20.28202, 'pm10_normalized': 0.21172518, 'so2_normalized': 37.435406, 'soot_normalized': 0.19763896}
# Raw:  {'pm10': 114.83, 'no2': 82.11, 'so2': 25.87, 'soot': 29.71}
# Transformed:  {'no2_normalized': 49.432022, 'pm10_normalized': 0.4003766, 'so2_normalized': 66.5854, 'soot_normalized': 0.23325133}
# Raw:  {'pm10': 75.4, 'no2': 61.62, 'so2': 20.27, 'soot': 24.95}
# Transformed:  {'no2_normalized': 28.94202, 'pm10_normalized': 0.2548086, 'so2_normalized': 46.095406, 'soot_normalized': 0.186424}
# Raw:  {'pm10': 67.47, 'no2': 39.94, 'so2': 19.6, 'soot': 19.67}
# Transformed:  {'no2_normalized': 7.26202, 'pm10_normalized': 0.22553255, 'so2_normalized': 24.415405, 'soot_normalized': 0.13448106}
# Raw:  {'pm10': 62.93, 'no2': 71.05, 'so2': 25.36, 'soot': 19.86}
# Transformed:  {'no2_normalized': 38.372025, 'pm10_normalized': 0.20877174, 'so2_normalized': 55.52541, 'soot_normalized': 0.13635023}
# Raw:  {'pm10': 114.03, 'no2': 86.51, 'so2': 30.76, 'soot': 29.9}
# Transformed:  {'no2_normalized': 53.832024, 'pm10_normalized': 0.39742312, 'so2_normalized': 70.98541, 'soot_normalized': 0.2351205}
# Raw:  {'pm10': 178.07, 'no2': 106.03, 'so2': 33.76, 'soot': 43.22}
# Transformed:  {'no2_normalized': 73.35202, 'pm10_normalized': 0.6338465, 'so2_normalized': 90.5054, 'soot_normalized': 0.3661584}
# Raw:  {'pm10': 98.0, 'no2': 82.28, 'so2': 27.73, 'soot': 31.5}
# Transformed:  {'no2_normalized': 49.60202, 'pm10_normalized': 0.33824345, 'so2_normalized': 66.7554, 'soot_normalized': 0.25086078}
# Raw:  {'pm10': 24.07, 'no2': 44.24, 'so2': 15.76, 'soot': 16.46}
# Transformed:  {'no2_normalized': 11.562023, 'pm10_normalized': 0.06530808, 'so2_normalized': 28.715408, 'soot_normalized': 0.10290211}
# Raw:  {'pm10': 24.03, 'no2': 42.27, 'so2': 18.57, 'soot': 14.21}
# Transformed:  {'no2_normalized': 9.592022, 'pm10_normalized': 0.065160416, 'so2_normalized': 26.745407, 'soot_normalized': 0.08076734}
# Raw:  {'pm10': 47.97, 'no2': 31.57, 'so2': 15.66, 'soot': 14.01}
# Transformed:  {'no2_normalized': -1.1079788, 'pm10_normalized': 0.1535423, 'so2_normalized': 16.045406, 'soot_normalized': 0.07879981}
